# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
bottom_up_data = np.loadtxt("result31.txt", dtype=int)
bottom_up_costs = bottom_up_data[:, 0]
bottom_up_x = np.arange(0, 350001, 10000)
bottom_up_x[-1] = 346025

# %%
top_down_data = np.loadtxt("result32.txt", dtype=int)
top_down_costs = top_down_data[:, 0]
top_down_x = np.arange(0, 150000 + 1, 10000)
top_down_x[-1] = 143535

# %%
fig, ax = plt.subplots()
ax.plot(bottom_up_x, bottom_up_costs, label="Parcours ascendant")
ax.plot(top_down_x, top_down_costs, label="Parcours descendant")
ax.axhline(y=820800, color="black", linestyle="dotted")
ax.set_xlabel("Tentatives de réécriture")
ax.set_ylabel("Coût des opérations")
ax.legend()
fig.savefig("progres_cout_operations.pdf", bbox_inches="tight")

# %%
bottom_up_depths = bottom_up_data[:, 2]
bottom_up_x = np.arange(0, 350001, 10000)
bottom_up_x[-1] = 346025

# %%
top_down_depths = top_down_data[:, 2]
top_down_x = np.arange(0, 150000 + 1, 10000)
top_down_x[-1] = 143535

# %%
fig, ax = plt.subplots()
ax.plot(bottom_up_x, bottom_up_depths, label="Parcours ascendant")
ax.plot(top_down_x, top_down_depths, label="Parcours descendant")
ax.axhline(y=29, color="black", linestyle="dotted")
ax.set_xlabel("Tentatives de réécriture")
ax.set_ylabel("Profondeur du circuit")
ax.legend()
fig.savefig("progres_profondeur_circuit.pdf", bbox_inches="tight")

# %%
bottom_up_depths = bottom_up_data[:, 2][1:-1]
bottom_up_depths = np.repeat(bottom_up_depths, 100)
bottom_up_data_rest = np.loadtxt("result31_.txt", dtype=int)
bottom_up_depths = np.concatenate((np.array([200]), bottom_up_depths, bottom_up_data_rest[:, 2][:61]))
bottom_up_x = np.arange(0, 346100 + 1, 100)
bottom_up_x[-1] = 346025
print(bottom_up_x.size, bottom_up_depths.size)
# Out:
# 3462 3462

# %%
top_down_xdepths = top_down_data[:, 1]
top_down_depths = top_down_data[:, 2]

# %%
fig, ax = plt.subplots()
ax.plot(bottom_up_x[-100:], bottom_up_depths[-100:], label="bottom_up_depths")
# ax.plot(top_down_x, top_down_depths, label="top_down_depths")
ax.legend()
